# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import seaborn as sms

# %%
import pandas as pd

# %%
host=pd.read_csv('raj.csv')

# %%
host.head()
# Out:
#         Zone  No. of Ambulance  2014  2015
# 0      Ajmer                83    99   108
# 1  Bharatpur                52    63    70
# 2    Bikaner                55    70    83
# 3    Jodhpur                97   126   156
# 4     Jaipur               111   134   152

# %%
len(host)
# Out:
# 7

# %%
list1 = sms.barplot(x='Zone' , y='2014' , data=host)

# %%
list2 = sms.barplot(x='Zone' , y='2015' , data=host)

# %%
sms.jointplot(x='2014' , y='2015', data=host , kind='kde')

# %%
host1=pd.read_csv('wisc.csv',index_col = "id")

# %%
host1.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean           ...             \
# id                                                     ...
# ...

# %%
list1 = sms.barplot(x='perimeter_mean' , y='area_mean' , data=host1)

# %%
host1.drop(host1.columns[-1], axis=1, inplace = True)

# %%
host1.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean       ...        \
# id                                                 ...
# ...

# %%
pip install plotly
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install plotly
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more informations on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
import plotly.tools as tls
tls.set_credentials_file(username='SACHIN777', api_key='••••••••••')
